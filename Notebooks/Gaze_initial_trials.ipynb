# %% [markdown]
# <a href="https://colab.research.google.com/github/259mit/GAZEtrack/blob/main/Notebooks/Gaze_initial_trials.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/hysts/pytorch_mpiigaze.git
# Out:
# Cloning into 'pytorch_mpiigaze'...
# remote: Enumerating objects: 599, done.
# remote: Counting objects: 100% (537/537), done.
# remote: Compressing objects: 100% (226/226), done.
# remote: Total 599 (delta 318), reused 517 (delta 299), pack-reused 62
# Receiving objects: 100% (599/599), 199.51 KiB | 6.04 MiB/s, done.
# Resolving deltas: 100% (345/345), done.

# %%
# !cd /content/pytorch_mpiigaze/ && mkdir -p datasets

# %%
# !cd /content/pytorch_mpiigaze/datasets && wget http://datasets.d2.mpi-inf.mpg.de/MPIIGaze/MPIIGaze.tar.gz
# Out:
# --2021-09-22 08:04:23--  http://datasets.d2.mpi-inf.mpg.de/MPIIGaze/MPIIGaze.tar.gz
# Resolving datasets.d2.mpi-inf.mpg.de (datasets.d2.mpi-inf.mpg.de)... 139.19.206.177
# Connecting to datasets.d2.mpi-inf.mpg.de (datasets.d2.mpi-inf.mpg.de)|139.19.206.177|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://datasets.d2.mpi-inf.mpg.de/MPIIGaze/MPIIGaze.tar.gz [following]
# --2021-09-22 08:04:23--  https://datasets.d2.mpi-inf.mpg.de/MPIIGaze/MPIIGaze.tar.gz
# Connecting to datasets.d2.mpi-inf.mpg.de (datasets.d2.mpi-inf.mpg.de)|139.19.206.177|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2102164307 (2.0G) [application/x-gzip]
# Saving to: ‘MPIIGaze.tar.gz’
#
# MPIIGaze.tar.gz     100%[===================>]   1.96G  19.1MB/s    in 2m 18s
#
# 2021-09-22 08:06:42 (14.6 MB/s) - ‘MPIIGaze.tar.gz’ saved [2102164307/2102164307]

# %%
# !tar xzvf /content/pytorch_mpiigaze/datasets/MPIIGaze.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# MPIIGaze/Data/Original/p06/day01/0292.jpg
# MPIIGaze/Data/Original/p06/day01/0244.jpg
# MPIIGaze/Data/Original/p06/day01/0182.jpg
# MPIIGaze/Data/Original/p06/day01/0153.jpg
# MPIIGaze/Data/Original/p06/day01/0295.jpg
# MPIIGaze/Data/Original/p06/day01/0238.jpg
# MPIIGaze/Data/Original/p06/day01/0077.jpg
# MPIIGaze/Data/Original/p06/day01/0166.jpg
# MPIIGaze/Data/Original/p06/day01/0271.jpg
# MPIIGaze/Data/Original/p06/day01/0329.jpg
# MPIIGaze/Data/Original/p06/day01/0093.jpg
# MPIIGaze/Data/Original/p06/day01/0042.jpg
# MPIIGaze/Data/Original/p06/day01/0094.jpg
# MPIIGaze/Data/Original/p06/day01/0045.jpg
# MPIIGaze/Data/Original/p06/day01/0161.jpg
# MPIIGaze/Data/Original/p06/day01/0276.jpg
# MPIIGaze/Data/Original/p06/day01/0039.jpg
# MPIIGaze/Data/Original/p06/day01/0113.jpg
# MPIIGaze/Data/Original/p06/day01/0204.jpg
# MPIIGaze/Data/Original/p06/day01/0278.jpg
# MPIIGaze/Data/Original/p06/day01/0320.jpg
# ...

# %%
# !python /content/pytorch_mpiigaze/tools/preprocess_mpiigaze.py --dataset /content/pytorch_mpiigaze/datasets/MPIIGaze -o datasets/
# Out:
# 100% 15/15 [00:21<00:00,  1.43s/it]

# %%
# !pip install -r /content/pytorch_mpiigaze/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 49 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 124 kB 16.3 MB/s
# ...
#      |████████████████████████████████| 636 kB 42.9 MB/s
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20210915-py3-none-any.whl size=60670 sha256=fa1df85f3c139a89d8f4672e2c7b9875896c5b97ebaf5c92e776c31786f279ca
#   Stored in directory: /root/.cache/pip/wheels/0e/e2/36/a659c9db2cf36699694e2651d1e458e88fb63b724c9458d3ab
# Successfully built fvcore
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !python /content/pytorch_mpiigaze/train.py --config /content/pytorch_mpiigaze/configs/mpiigaze/lenet_train.yaml
# Out:
# [2021-09-22 08:11:30] __main__ INFO: mode: MPIIGaze
# dataset:
#   dataset_dir: datasets/MPIIGaze.h5
# transform:
#   mpiifacegaze_face_size: 224
#   mpiifacegaze_gray: False
# device: cpu
# model:
#   name: lenet
#   backbone:
#     name: resnet_simple
#     pretrained: resnet18
#     resnet_block: basic
#     resnet_layers: [2, 2, 2]
# train:
#   batch_size: 32
#   optimizer: sgd
#   base_lr: 0.01
#   momentum: 0.9
#   nesterov: True
#   weight_decay: 0.0001
#   no_weight_decay_on_bn: False
#   loss: L2
#   seed: 0
#   val_first: True
#   val_period: 1
#   test_id: 0
#   val_ratio: 0.1
#   output_dir: experiments/mpiigaze/lenet/exp00
#   log_period: 100
#   checkpoint_period: 10
#   use_tensorboard: True
#   train_dataloader:
#     num_workers: 4
#     drop_last: True
#     pin_memory: False
#   val_dataloader:
#     num_workers: 4
#     pin_memory: False
# tensorboard:
#   train_images: False
#   val_images: False
#   model_params: False
# optim:
#   adam:
# ...

# %%
# !python /content/pytorch_mpiigaze/evaluate.py --config /content/pytorch_mpiigaze/configs/mpiigaze/lenet_eval.yaml
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0% 0/12 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 100% 12/12 [00:03<00:00,  3.91it/s]
# The mean angle error (deg): 4.37
